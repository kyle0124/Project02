# %%
import os
from google.colab import drive
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.chdir('/content/drive/MyDrive/TensorFlow/99. Project/Face_Predict')

# %%
# !ls -l
# Out:
# total 704705
# drwx------ 2 root root      4096 Mar 18 08:41 Code
# -rw------- 1 root root   1060692 Mar 18 05:25 data01.csv
# -rw------- 1 root root    169233 Mar 21 00:56 data01_undersampled_20.csv
# -rw------- 1 root root    502954 Mar 21 00:44 data01_undersampled.csv
# -rw------- 1 root root        66 Mar 18 00:39 kaggle.json
# drwx------ 2 root root      4096 Mar 18 14:24 keras_vggface
# -rw------- 1 root root    470357 Mar 14 07:00 sample01.ipynb
# -rw------- 1 root root     89325 Mar 14 08:24 sample02.ipynb
# drwx------ 4 root root      4096 Mar 21 01:13 Test
# drwx------ 2 root root      4096 Mar 21  2024 Test_20
# drwx------ 4 root root      4096 Mar 21 01:14 Train
# drwx------ 2 root root      4096 Mar 21  2024 Train_20
# -rw------- 1 root root  34253632 Mar 21 01:00 Train_Test_20.zip
# -rw------- 1 root root 104955102 Mar 21 01:01 Train_Test_All.zip
# drwx------ 2 root root      4096 Mar 18 00:42 UTKFace
# -rw------- 1 root root 580085408 Mar 15 00:07 vgg_face_weights.h5

# %%
# !unzip Train_Test_All.zip
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: Train/Race/Black/26_0_1_20170116003707203.jpg.chip.jpg
#   inflating: Train/Race/Black/26_0_1_20170116005302166.jpg.chip.jpg
#   inflating: Train/Race/Black/26_0_1_20170116010015989.jpg.chip.jpg
#   inflating: Train/Race/Black/26_0_1_20170116010019224.jpg.chip.jpg
#   inflating: Train/Race/Black/26_0_1_20170116010114628.jpg.chip.jpg
#   inflating: Train/Race/Black/26_0_1_20170116010315712.jpg.chip.jpg
#   inflating: Train/Race/Black/26_0_1_20170116010432759.jpg.chip.jpg
#   inflating: Train/Race/Black/26_0_1_20170116010530676.jpg.chip.jpg
#   inflating: Train/Race/Black/26_0_1_20170116010639525.jpg.chip.jpg
#   inflating: Train/Race/Black/26_0_1_20170116010816035.jpg.chip.jpg
#   inflating: Train/Race/Black/26_0_1_20170116024208336.jpg.chip.jpg
#   inflating: Train/Race/Black/26_0_1_20170116024617265.jpg.chip.jpg
#   inflating: Train/Race/Black/26_0_1_20170116024646322.jpg.chip.jpg
# ...

# %%
# !unzip Train_Test_20.zip
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: Train_20/Gender/Female/25_1_1_20170116223020576.jpg.chip.jpg
#   inflating: Train_20/Gender/Female/25_1_1_20170116223829647.jpg.chip.jpg
#   inflating: Train_20/Gender/Female/25_1_1_20170117125908204.jpg.chip.jpg
#   inflating: Train_20/Gender/Female/25_1_1_20170117135941266.jpg.chip.jpg
#   inflating: Train_20/Gender/Female/25_1_1_20170117142659506.jpg.chip.jpg
#   inflating: Train_20/Gender/Female/25_1_1_20170117151909157.jpg.chip.jpg
#   inflating: Train_20/Gender/Female/25_1_1_20170117154035392.jpg.chip.jpg
#   inflating: Train_20/Gender/Female/25_1_1_20170117170628763.jpg.chip.jpg
#   inflating: Train_20/Gender/Female/25_1_1_20170117192036085.jpg.chip.jpg
#   inflating: Train_20/Gender/Female/25_1_1_20170117195334509.jpg.chip.jpg
#   inflating: Train_20/Gender/Female/25_1_2_20161219194224315.jpg.chip.jpg
#   inflating: Train_20/Gender/Female/25_1_2_20161219194415803.jpg.chip.jpg
# ...

# %%
test = len(os.listdir('./Test/Gender/Female/')) + len(os.listdir('./Test/Gender/Male'))
test
# Out:
# 1876

# %%
len(os.listdir('./Test/Race/Black/')) + len(os.listdir('./Test/Race/White')) + len(os.listdir('./Test/Race/Asian'))
# Out:
# 1876

# %%
train = len(os.listdir('./Train/Gender/Female/')) + len(os.listdir('./Train/Gender/Male'))
train
# Out:
# 8399

# %%
len(os.listdir('./Train/Race/Black/')) + len(os.listdir('./Train/Race/White')) + len(os.listdir('./Train/Race/Asian'))
# Out:
# 8399

# %%
total = len(os.listdir('./Test/Gender/Female/')) + len(os.listdir('./Test/Gender/Male')) + len(os.listdir('./Train/Gender/Female/')) + len(os.listdir('./Train/Gender/Male'))
total
# Out:
# 10275

# %%
train / total
# Out:
# 0.8174209245742092

# %%
############################################################

# %%
test_20 = len(os.listdir('./Test_20/Gender/Female/')) + len(os.listdir('./Test_20/Gender/Male'))
test_20
# Out:
# 612

# %%
len(os.listdir('./Test_20/Race/Black/')) + len(os.listdir('./Test_20/Race/White')) + len(os.listdir('./Test_20/Race/Asian'))
# Out:
# 612

# %%
train_20 = len(os.listdir('./Train_20/Gender/Female/')) + len(os.listdir('./Train_20/Gender/Male'))
train_20
# Out:
# 2841

# %%
len(os.listdir('./Train_20/Race/Black/')) + len(os.listdir('./Train_20/Race/White')) + len(os.listdir('./Train_20/Race/Asian'))
# Out:
# 2841

# %%
total_20 = len(os.listdir('./Test_20/Gender/Female/')) + len(os.listdir('./Test_20/Gender/Male')) + len(os.listdir('./Train_20/Gender/Female/')) + len(os.listdir('./Train_20/Gender/Male'))
total_20
# Out:
# 3453

# %%
train_20 / total_20
# Out:
# 0.8227628149435273
